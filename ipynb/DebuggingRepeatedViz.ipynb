# %%
# %pylab inline 
# %load_ext autoreload
# %autoreload 2
from vizDashboard import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['get_cmap']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
with open('../experiment/nodeDic.json', 'r') as myfile:
    nodeDicStr=myfile.read().replace('\n', '').decode('string_escape')

# %%
nodeDicStr.count("#has_impressions_tbl$0#has_actions_tbl$1#has_distinct$1#")
# Out:
# 0

# %%
generateDashboard(nodeDicStr,"survived","COUNT(id)",4,"Titanic greedy [k=10; total utility =256.77]")

# %%
generateDashboard(nodeDicStr,"survived","COUNT(id)",2,"Titanic greedy [k=10; total utility =256.77]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-8bba449b7f29> in <module>()
# ----> 1 generateDashboard(nodeDicStr,"survived","COUNT(id)",2,"Titanic greedy [k=10; total utility =256.77]")
#
# /Users/dorislee/Desktop/Research/viz-sum/ipynb/vizDashboard.py in generateDashboard(nodeDicStr, xlabel, ylabel, numBars, title, fname)
#      79                 yVals.append(bar["yAxis"])
#      80             if i==numBars:
# ---> 81                 filterName=bar['filter']
#      82                 if filterName=="#":
#      83                     filterName="Root"
#
# KeyError: 'filter'
