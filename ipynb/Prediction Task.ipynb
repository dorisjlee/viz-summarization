# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from paper_visualization import *

# %% [markdown]
# ```
# summarization=# SELECT stop_outcome, COUNT(*) FROM ct_police_stop WHERE contraband_found = 't' AND driver_race = 'White' GROUP BY stop_outcome ;
#  stop_outcome | count
# --------------+-------
#  ticket       |   646
#  warn         |    49
#  arrest       |   477
# (3 rows)
# ```

# %%
print 'ticket:',646./(646+49+477)
print 'warn:',49./(646+49+477)
print 'arrest:',477./(646+49+477)
# Out:
# ticket: 0.551194539249
# warn: 0.0418088737201
# arrest: 0.406996587031

# %%
bar_chart([55.12,4.18,40.70], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="contraband_found = 't', driver_race = 'White' ", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0,0], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="contraband_found = 't', driver_race = 'White' ", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT stop_outcome, COUNT(*) FROM ct_police_stop WHERE contraband_found = 't' AND driver_race = 'Hispanic' GROUP BY stop_outcome ;
#  stop_outcome | count
# --------------+-------
#  arrest       |   124
#  ticket       |   142
#  warn         |    12
# (3 rows)
# ```

# %%
print 'ticket:',142./(124+142+12)
print 'warn:',12./(124+142+12)
print 'arrest:',124./(124+142+12)
# Out:
# ticket: 0.510791366906
# warn: 0.0431654676259
# arrest: 0.446043165468

# %%
bar_chart([51.08,4.31,44.60], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="contraband_found = 't', driver_race = 'Hispanic' ", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0,0], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="contraband_found = 't', driver_race = 'Hispanic' ", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT stop_outcome, COUNT(*) FROM ct_police_stop WHERE  stop_time= 'Afternoon' AND driver_age= '22-29' AND search_conducted='t'  GROUP BY stop_outcome ;
#  stop_outcome | count
# --------------+-------
#  arrest       |   161
#  ticket       |   249
#  warn         |    56
# (3 rows)
# ```

# %%
print 'ticket:',249./(249+161+56)
print 'warn:',56./(249+161+56)
print 'arrest:',161./(249+161+56)
# Out:
# ticket: 0.534334763948
# warn: 0.12017167382
# arrest: 0.345493562232

# %%
bar_chart([53.43,12.02,34.55], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="stop_time= 'Afternoon', driver_age= '22-29',\n search_conducted='t' ", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0,0], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="stop_time= 'Afternoon', driver_age= '22-29',\n search_conducted='t' ", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT contraband_found, duration, stop_outcome, COUNT(*) FROM ct_police_stop WHERE contraband_found = 't' AND duration = '30+ min' GROUP BY contraband_found, duration, stop_outcome ORDER BY contraband_found, duration, stop_outcome;
#  contraband_found | duration | stop_outcome | count
# ------------------+----------+--------------+-------
#  t                | 30+ min  | arrest       |   353
#  t                | 30+ min  | ticket       |   247
#  t                | 30+ min  | warn         |    14
# (3 rows)
# ```

# %%
bar_chart([40.23,2.28,57.49], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops", title="contraband_found = 't', duration = '30+ min'", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0,0], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops", title="contraband_found = 't', duration = '30+ min'", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT  stop_outcome,COUNT(*) FROM ct_police_stop WHERE stop_time = 'Afternoon' AND driver_gender = 'M' AND search_conducted='t' GROUP BY stop_outcome ;
#  stop_outcome | count
# --------------+-------
#  arrest       |   334
#  ticket       |   442
#  warn         |   104
# (3 rows)
# ```

# %%
print 334./(334+442+104)
print 442./(334+442+104)
print 104./(334+442+104)
# Out:
# 0.379545454545
# 0.502272727273
# 0.118181818182

# %%
bar_chart([50.22,11.82,37.95], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="stop_time = 'Afternoon',\n driver_gender = 'M',\n search_conducted='t'", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0,0], ['ticket','warn','arrest'], xtitle="stop_outcome", ytitle="% of police stops",
          title="stop_time = 'Afternoon',\n driver_gender = 'M',\n search_conducted='t'", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT autism, COUNT(*) FROM autism WHERE a6_score=1 AND a4_score=1 GROUP BY autism;
#  autism | count
# --------+-------
#  NO     |    25
#  YES    |   121
# (2 rows)
# ```

# %%
print 25./(25+121)
print 121./(25+121)
# Out:
# 0.171232876712
# 0.828767123288

# %%
bar_chart([17.12,82.88], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a6_score=1, a4_score=1", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a6_score=1, a4_score=1", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT autism, COUNT(*) FROM autism WHERE a9_score=1 AND a2_score=1 AND a8_score=0 GROUP BY autism;
#  autism | count
# --------+-------
#  NO     |    16
#  YES    |    23
# (2 rows)
# ```

# %%
print 16./(16+23)
print 23./(16+23)
# Out:
# 0.410256410256
# 0.589743589744

# %%
bar_chart([41.03,58.97], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a9_score=1,a2_score=1,\n a8_score=0", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a9_score=1,a2_score=1,\n a8_score=0", top_right_text="", N=1, width=0.1,autolabel_flag=False)

# %% [markdown]
# ```
# summarization=# SELECT autism, COUNT(*) FROM autism WHERE a3_score = 1 AND a9_score = 1 GROUP BY autism;
#  autism | count
# --------+-------
#  NO     |    27
#  YES    |   129
# (2 rows)
# ```

# %%
print 27./(27+129)
print 129./(27+129)
# Out:
# 0.173076923077
# 0.826923076923

# %%
bar_chart([17.31,82.69], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a3_score = 1, a9_score = 1", top_right_text="", N=1, width=0.1)

# %%
bar_chart([0,0], ['NO','YES'], xtitle="autism", ytitle="% of participants",
          title="a3_score = 1, a9_score = 1", top_right_text="", N=1, width=0.1,autolabel_flag=False)
