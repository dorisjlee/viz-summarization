# %%
# %pylab inline 
# %load_ext autoreload
# %autoreload 2
from vizOutput import * 
import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for fname in glob.glob("dashboards/json/*"):
    datasetname, xAxis,algo,dist,ic,ip,k,nbar = fname[:-5].split("/")[-1].split("_")
    ic = float(ic[2:])
    ip = float(ip[2:])
    k = int(k[1:])
    nbar = int(nbar[4:])
    with open(fname, 'r') as myfile:
        nodeDicStr=myfile.read().replace('\n', '').decode('string_escape')
    generateDashboard(nodeDicStr,xAxis,"COUNT",nbar,"{} {} [k={}]".format(datasetname,algo,k),fname[:-5].split("/")[-1]+".pdf")
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
